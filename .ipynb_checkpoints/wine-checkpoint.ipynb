# %%
import requests
import flickrapi
import urllib.request
import pandas as pd

from pprint import pprint
from config import api_key, api_secret

# %%
#downloaded using these libraries: https://stuvel.eu/flickrapi & https://www.flickr.com/services/api/explore/flickr.photos.search

#authenticate and format 
flickr = flickrapi.FlickrAPI(api_key, api_secret, format='parsed-json')

#call flickr photo search API
sets = flickr.photos.search(tags='wine bottle', per_page='100', page= 1)

#this will give json

# %%
#using json, https://stackoverflow.com/questions/21328137/get-photos-from-flickr-photos-api put what was needed in an url format.

wine_photos = sets['photos']['photo']
wine_photos

wine_urls = []

#created empty dictionary and loop through the wine photos, which is a list.
for photo in wine_photos:
    url = f"http://farm{photo['farm']}.staticflickr.com/{photo['server']}/{photo['id']}_{photo['secret']}.jpg"
    wine_urls.append(url)

# %%
#download the photos and save. Add code to skip the error.
count = 0
for url in wine_urls:
    try:
        urllib.request.urlretrieve(url, f"wine_photos/winebottle{count}.jpg")
        count += 1
    except:
        print('skip')

# %%
photo1 = sets['photos']['photo'][0]
photo1
# Out:
# {'id': '40581590273',
#  'owner': '68130272@N03',
#  'secret': 'db60f6ac08',
#  'server': '7887',
#  'farm': 8,
#  'title': 'Wino',
#  'ispublic': 1,
#  'isfriend': 0,
#  'isfamily': 0}

# %%
wine_urls
# Out:
# ['http://farm8.staticflickr.com/7887/40581590273_db60f6ac08.jpg',
#  'http://farm8.staticflickr.com/7801/47494816732_14bb304121.jpg',
#  'http://farm8.staticflickr.com/7817/33670992648_605c9ee1f5.jpg',
#  'http://farm8.staticflickr.com/7853/47545501301_50fa8f3f92.jpg',
#  'http://farm8.staticflickr.com/7866/46750799664_b47ba5d04c.jpg',
#  'http://farm8.staticflickr.com/7809/40504884063_9e92851929.jpg',
#  'http://farm8.staticflickr.com/7916/40478208163_aa7ea39a0f.jpg',
#  'http://farm8.staticflickr.com/7837/47287969812_e20f0cc762.jpg',
#  'http://farm8.staticflickr.com/7848/32357833877_9fe92c4da0.jpg',
#  'http://farm8.staticflickr.com/7859/47298500101_170fc7f2e2.jpg',
#  'http://farm8.staticflickr.com/7801/47237796902_29e33c66e9.jpg',
#  'http://farm8.staticflickr.com/7803/47267461581_b4b1ac068c.jpg',
#  'http://farm8.staticflickr.com/7919/46291909185_d136f8442f.jpg',
#  'http://farm8.staticflickr.com/7922/47203123141_7964c6b92a.jpg',
#  'http://farm8.staticflickr.com/7811/40236628073_256a8857e6.jpg',
#  'http://farm8.staticflickr.com/7911/46256697425_03c0fee823.jpg',
#  'http://farm8.staticflickr.com/7881/47108881282_0b44796721.jpg',
#  'http://farm8.staticflickr.com/7826/47114030621_425dac01e6.jpg',
#  'http://farm8.staticflickr.com/7889/47030558762_233b4c85f6.jpg',
#  'http://farm8.staticflickr.com/7902/40113810303_70908169b3.jpg',
#  'http://farm8.staticflickr.com/7802/47046876501_782806d7a3.jpg',
#  'http://farm8.staticflickr.com/7852/33156657828_aa883a7d99.jpg',
#  'http://farm8.staticflickr.com/7922/46970103272_a9cfec4ebd.jpg',
#  'http://farm8.staticflickr.com/7827/46260113344_a56b892bfa.jpg',
#  'http://farm5.staticflickr.com/4856/46060842175_1edd7898fc.jpg',
#  'http://farm8.staticflickr.com/7909/46053680335_6809791a8e.jpg',
#  'http://farm5.staticflickr.com/4822/46900582712_4dba3029f6.jpg',
#  'http://farm8.staticflickr.com/7803/46900582592_e0ddbf8fbf.jpg',
#  'http://farm8.staticflickr.com/7905/39979995353_f8cc717f65.jpg',
#  'http://farm8.staticflickr.com/7910/46941331311_4c902946fe.jpg',
#  'http://farm5.staticflickr.com/4870/46198818874_bdc1d55e99.jpg',
#  'http://farm8.staticflickr.com/7835/39946253383_59e3d70595.jpg',
#  'http://farm8.staticflickr.com/7851/46159955684_90bd3d2a1f.jpg',
#  'http://farm5.staticflickr.com/4891/46832967702_587203a427.jpg',
#  'http://farm8.staticflickr.com/7889/46832946672_585d79a607.jpg',
#  'http://farm8.staticflickr.com/7807/46159937634_3c98846c74.jpg',
#  'http://farm8.staticflickr.com/7926/45970219015_b2a2b173c0.jpg',
#  'http://farm5.staticflickr.com/4839/46884914741_e9420899ef.jpg',
#  'http://farm5.staticflickr.com/4807/33009558888_b03909afae.jpg',
#  'http://farm8.staticflickr.com/7870/32996713278_e7ee4cef72.jpg',
#  'http://farm5.staticflickr.com/4901/39907246963_d82c1e80cc.jpg',
#  'http://farm8.staticflickr.com/7913/39907758323_78e149c009.jpg',
#  'http://farm5.staticflickr.com/4896/46118543424_49a12a6f09.jpg',
#  'http://farm8.staticflickr.com/7827/39865161003_77ebf2b959.jpg',
#  'http://farm5.staticflickr.com/4884/46778189822_1b4c6d144c.jpg',
#  'http://farm5.staticflickr.com/4870/39865160813_ce022b9c48.jpg',
#  'http://farm8.staticflickr.com/7805/39865158503_b32e16e864.jpg',
#  'http://farm5.staticflickr.com/4814/31887866637_d4f0c233b3.jpg',
#  'http://farm5.staticflickr.com/4811/46817761301_65249941e9.jpg',
#  'http://farm5.staticflickr.com/4808/32942064158_30d91984b4.jpg',
#  'http://farm5.staticflickr.com/4850/32942063688_6a7b467389.jpg',
#  'http://farm5.staticflickr.com/4900/46817760281_af6419a586.jpg',
#  'http://farm5.staticflickr.com/4824/46088122924_f611f799ef.jpg',
#  'http://farm5.staticflickr.com/4906/31870339097_4bbe5aeedc.jpg',
#  'http://farm5.staticflickr.com/4878/45887306325_0c138eebcd.jpg',
#  'http://farm8.staticflickr.com/7878/39827526083_a2cee13472.jpg',
#  'http://farm5.staticflickr.com/4908/46050290304_f884e1c232.jpg',
#  'http://farm5.staticflickr.com/4893/46033868144_e9881090d5.jpg',
#  'http://farm5.staticflickr.com/4884/46758906061_160fee1f1e.jpg',
#  'http://farm8.staticflickr.com/7886/31817123717_b989e87619.jpg',
#  'http://farm5.staticflickr.com/4853/45843686815_fcb92e233a.jpg',
#  'http://farm8.staticflickr.com/7877/46758886941_1d80501a15.jpg',
#  'http://farm8.staticflickr.com/7890/32883166748_84233f4c31.jpg',
#  'http://farm5.staticflickr.com/4872/32859844588_02195bca4d.jpg',
#  'http://farm8.staticflickr.com/7840/39752465473_b69ba8c9d5.jpg',
#  'http://farm5.staticflickr.com/4850/39723107153_d120296b6b.jpg',
#  'http://farm8.staticflickr.com/7904/32813037998_4357d696be.jpg',
#  'http://farm8.staticflickr.com/7871/32813032398_97101c6cbf.jpg',
#  'http://farm8.staticflickr.com/7881/46636830621_9414fbdde7.jpg',
#  'http://farm8.staticflickr.com/7924/39663409083_920529ddaa.jpg',
#  'http://farm8.staticflickr.com/7855/44777264990_aa0410417a.jpg',
#  'http://farm8.staticflickr.com/7899/32720837278_cd028631f9.jpg',
#  'http://farm5.staticflickr.com/4854/32720836598_1a07fd09ba.jpg',
#  'http://farm5.staticflickr.com/4881/46561319141_6bfa77bfee.jpg',
#  'http://farm5.staticflickr.com/4916/32676818838_5eec681e27.jpg',
#  'http://farm5.staticflickr.com/4826/46529191891_04b17dce77.jpg',
#  'http://farm8.staticflickr.com/7837/32655786918_df58c8b9b8.jpg',
#  'http://farm5.staticflickr.com/4916/44627306210_f28f2e544c.jpg',
#  'http://farm5.staticflickr.com/4915/46371574242_a5efdfb194.jpg',
#  'http://farm5.staticflickr.com/4883/44603844820_19373c220c.jpg',
#  'http://farm8.staticflickr.com/7875/31478704007_f5f1e7bdd0.jpg',
#  'http://farm5.staticflickr.com/4859/46349846952_37b1711921.jpg',
#  'http://farm5.staticflickr.com/4805/45644085274_2b743a3417.jpg',
#  'http://farm5.staticflickr.com/4846/45424923055_69d17c3339.jpg',
#  'http://farm5.staticflickr.com/4815/45608914374_6169f6a59d.jpg',
#  'http://farm5.staticflickr.com/4828/46266854802_29f1b32703.jpg',
#  'http://farm5.staticflickr.com/4819/32429310348_85e808c25f.jpg',
#  'http://farm2.staticflickr.com/1976/46194521102_7571e4605a.jpg',
#  'http://farm5.staticflickr.com/4898/46184632872_79a593f2d9.jpg',
#  'http://farm5.staticflickr.com/4870/32327127928_8d5c7d45a1.jpg',
#  'http://farm5.staticflickr.com/4879/31260067067_b3f0e802ae.jpg',
#  'http://farm5.staticflickr.com/4912/31260066927_81a246472c.jpg',
#  'http://farm5.staticflickr.com/4852/44378683810_43cf3c8bfe.jpg',
#  'http://farm5.staticflickr.com/4916/32323783558_cb3651430f.jpg',
#  'http://farm5.staticflickr.com/4898/44378683520_fc2fb7bc68.jpg',
#  'http://farm5.staticflickr.com/4905/32323782308_3e04a2c6f9.jpg',
#  'http://farm5.staticflickr.com/4873/32323782008_de44033274.jpg',
#  'http://farm5.staticflickr.com/4830/32318356518_937b7edc97.jpg',
#  'http://farm5.staticflickr.com/4807/46055185512_26164bbcd8.jpg',
#  'http://farm8.staticflickr.com/7879/46224216855_90a7596778.jpg']

# %%
df = pd.DataFrame({"wine photos": wine_urls})
df
# Out:
#                                           wine photos
# 0   http://farm8.staticflickr.com/7887/40581590273...
# 1   http://farm8.staticflickr.com/7801/47494816732...
# 2   http://farm8.staticflickr.com/7817/33670992648...
# 3   http://farm8.staticflickr.com/7853/47545501301...
# 4   http://farm8.staticflickr.com/7866/46750799664...
# 5   http://farm8.staticflickr.com/7809/40504884063...
# 6   http://farm8.staticflickr.com/7916/40478208163...
# 7   http://farm8.staticflickr.com/7837/47287969812...
# 8   http://farm8.staticflickr.com/7848/32357833877...
# 9   http://farm8.staticflickr.com/7859/47298500101...
# 10  http://farm8.staticflickr.com/7801/47237796902...
# 11  http://farm8.staticflickr.com/7803/47267461581...
# 12  http://farm8.staticflickr.com/7919/46291909185...
# 13  http://farm8.staticflickr.com/7922/47203123141...
# 14  http://farm8.staticflickr.com/7811/40236628073...
# 15  http://farm8.staticflickr.com/7911/46256697425...
# 16  http://farm8.staticflickr.com/7881/47108881282...
# 17  http://farm8.staticflickr.com/7826/47114030621...
# 18  http://farm8.staticflickr.com/7889/47030558762...
# 19  http://farm8.staticflickr.com/7902/40113810303...
# 20  http://farm8.staticflickr.com/7802/47046876501...
# 21  http://farm8.staticflickr.com/7852/33156657828...
# 22  http://farm8.staticflickr.com/7922/46970103272...
# 23  http://farm8.staticflickr.com/7827/46260113344...
# 24  http://farm5.staticflickr.com/4856/46060842175...
# 25  http://farm8.staticflickr.com/7909/46053680335...
# 26  http://farm5.staticflickr.com/4822/46900582712...
# 27  http://farm8.staticflickr.com/7803/46900582592...
# 28  http://farm8.staticflickr.com/7905/39979995353...
# 29  http://farm8.staticflickr.com/7910/46941331311...
# ..                                                ...
# 70  http://farm8.staticflickr.com/7855/44777264990...
# 71  http://farm8.staticflickr.com/7899/32720837278...
# 72  http://farm5.staticflickr.com/4854/32720836598...
# 73  http://farm5.staticflickr.com/4881/46561319141...
# 74  http://farm5.staticflickr.com/4916/32676818838...
# 75  http://farm5.staticflickr.com/4826/46529191891...
# 76  http://farm8.staticflickr.com/7837/32655786918...
# 77  http://farm5.staticflickr.com/4916/44627306210...
# 78  http://farm5.staticflickr.com/4915/46371574242...
# 79  http://farm5.staticflickr.com/4883/44603844820...
# 80  http://farm8.staticflickr.com/7875/31478704007...
# 81  http://farm5.staticflickr.com/4859/46349846952...
# 82  http://farm5.staticflickr.com/4805/45644085274...
# 83  http://farm5.staticflickr.com/4846/45424923055...
# 84  http://farm5.staticflickr.com/4815/45608914374...
# 85  http://farm5.staticflickr.com/4828/46266854802...
# 86  http://farm5.staticflickr.com/4819/32429310348...
# 87  http://farm2.staticflickr.com/1976/46194521102...
# 88  http://farm5.staticflickr.com/4898/46184632872...
# 89  http://farm5.staticflickr.com/4870/32327127928...
# 90  http://farm5.staticflickr.com/4879/31260067067...
# 91  http://farm5.staticflickr.com/4912/31260066927...
# 92  http://farm5.staticflickr.com/4852/44378683810...
# 93  http://farm5.staticflickr.com/4916/32323783558...
# 94  http://farm5.staticflickr.com/4898/44378683520...
# 95  http://farm5.staticflickr.com/4905/32323782308...
# 96  http://farm5.staticflickr.com/4873/32323782008...
# 97  http://farm5.staticflickr.com/4830/32318356518...
# 98  http://farm5.staticflickr.com/4807/46055185512...
# 99  http://farm8.staticflickr.com/7879/46224216855...
#
# [100 rows x 1 columns]

# %%
df.to_csv("winephotos.csv")
